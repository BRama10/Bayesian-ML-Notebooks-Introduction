# %% [markdown]
# <a href="https://colab.research.google.com/github/BRama10/Bayesian-ML-Notebooks-Introduction/blob/main/Bayesian_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Diabetes Data Set Test

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/coreyjwade/bca_datasets/master/diabetes.csv', nrows = 200)

df

X = df.iloc[:,:-1]
y=df.iloc[:,-1]
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 195            5      158             84             41      210  39.4
# 196            1      105             58              0        0  24.3
# 197            3      107             62             13       48  22.9
# 198            4      109             64             44       99  34.8
# 199            4      148             60             27      318  30.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
def df_split(arr, train, test, predict):
  if(type(train) == float or type(test) == float or type(predict) == float):
    num = len(arr)
    train1, test1, predict1 = int(num * train), int(num * test), int(num*predict)
  else:
    train1, test1, predict1 = train,test, predict
  arr_train = arr.sample(n=train1)
  arr.drop(index=arr_train.index.tolist(), inplace = True)
  arr_test = arr.sample(n=test1)
  arr.drop(index=arr_test.index.tolist(), inplace = True)
  arr_predict = arr
  return arr_train, arr_test, arr_predict



df1,df2,df3 = df_split(df, 0.5,0.3,0.2)
df1

# %%
#arr (type = Dataframe) - A dataframe with > 1 rows and columns
#train (type = int, float) - Size of training dataset. If int, then specifies the integer length of the new dataset. If float, then specifies the fraction of arr to be returned.
#test (type = int, float) - Size of testing dataset. If int, then specifies the integer length of the new dataset. If float, then specifies the fraction of arr to be returned.
#predict (type = int, float) - Size of predicting dataset. If int, then specifies the integer length of the new dataset. If float, then specifies the fraction of arr to be returned.
#Note - type of train, test, predict must all be same. Ex. They all should be ints, or they all should be floats.

def df_split(arr, train, test, predict):
  try:
    arr_train = arr.sample(n=train)
    arr.drop(index=arr_train.index.tolist(), inplace = True)
    arr_test = arr.sample(n=test)
    arr.drop(index=arr_test.index.tolist(), inplace = True)
    arr_predict = arr
  except:
    num = len(arr)
    train1, test1, predict1 = int(num * train), int(num * test), int(num*predict)
    arr_train, arr_test, arr_predict = df_split(arr, train1, test1, predict1)
  finally:
    return arr_train, arr_test, arr_predict

# %%
a,b,c = df_split(df, 0.9,0,0.1)

# %%
len(b)
# Out:
# 0

# %% [markdown]
# #Ionosphere dataset test

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/ionosphere.csv')
X, y = df.iloc[:, :-1], df.iloc[:, -1]
df
# Out:
#      1  0  0.99539  -0.05889  0.85243  0.02306  0.83398  -0.37708      1.1  \
# 0    1  0  1.00000  -0.18829  0.93035 -0.36156 -0.10868  -0.93597  1.00000
# 1    1  0  1.00000  -0.03365  1.00000  0.00485  1.00000  -0.12062  0.88965
# 2    1  0  1.00000  -0.45161  1.00000  1.00000  0.71216  -1.00000  0.00000
# 3    1  0  1.00000  -0.02401  0.94140  0.06531  0.92106  -0.23255  0.77152
# 4    1  0  0.02337  -0.00592 -0.09924 -0.11949 -0.00763  -0.11824  0.14706
# ..  .. ..      ...       ...      ...      ...      ...       ...      ...
# 345  1  0  0.83508   0.08298  0.73739 -0.14706  0.84349  -0.05567  0.90441
# 346  1  0  0.95113   0.00419  0.95183 -0.02723  0.93438  -0.01920  0.94590
# 347  1  0  0.94701  -0.00034  0.93207 -0.03227  0.95177  -0.03431  0.95584
# 348  1  0  0.90608  -0.01657  0.98122 -0.01989  0.95691  -0.03646  0.85746
# 349  1  0  0.84710   0.13533  0.73638 -0.06151  0.87873   0.08260  0.88928
#
# ...

# %% [markdown]
# #Work

# %%
# !pip install scikit-optimize
import skopt
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.svm import SVC

print('skopt %s' % skopt.__version__)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# skopt 0.9.0

# %%
from numpy import mean,std
import skopt

clf = SVC()
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
m_scores = cross_val_score(clf, X, y, scoring='accuracy', cv=cv, n_jobs=-1, error_score='raise')
#print('Accuracy: %.3f (%.3f)' % (mean(m_scores), std(m_scores)))
mean(m_scores)
# Out:
# 0.7565162907268171

# %%
from skopt.space.space import Real, Categorical, Integer
from skopt.utils import use_named_args
from skopt import gp_minimize

params = list()
params.append(Real(1e-6, 100.0, 'log-uniform', name='C'))
params.append(Categorical(['linear', 'poly', 'rbf', 'sigmoid'], name='kernel'))
params.append(Integer(1, 5, name='degree'))
params.append(Real(1e-6, 100.0, 'log-uniform', name='gamma'))

# %%
#Manual Tuning of Hyperparameters using skopt

@use_named_args(params)
def optimize_model(**params):
  clf = SVC()
  clf.set_params(**params)
  cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
  result = cross_val_score(clf, X, y, cv=cv, n_jobs=-1, scoring='accuracy')
  avg_result = mean(result)
  return 1.0 - avg_result

score = gp_minimize(optimize_model, params)

print('Best Accuracy: %.3f' % (1.0 - score.fun))
print('Best Parameters: %s' % (score.x))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-06f5d30e1232> in <module>()
#      10   return 1.0 - avg_result
#      11
# ---> 12 score = gp_minimize(optimize_model, params)
#      13
#      14 print('Best Accuracy: %.3f' % (1.0 - score.fun))
#
# /usr/local/lib/python3.7/dist-packages/skopt/optimizer/gp.py in gp_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, noise, n_jobs, model_queue_size)
#     266         n_restarts_optimizer=n_restarts_optimizer,
#     267         x0=x0, y0=y0, random_state=rng, verbose=verbose,
# --> 268         callback=callback, n_jobs=n_jobs, model_queue_size=model_queue_size)
#
# ...

# %%
from skopt.space.space import Real, Categorical, Integer
from skopt.utils import use_named_args
from skopt import BayesSearchCV

params = dict()
#params['C'] = (1e-6, 100.0, 'log-uniform')
#params['gamma'] = (1e-6, 100.0, 'log-uniform')
params['degree'] = (1,5)
params['kernel'] = ['linear', 'poly', 'rbf', 'sigmoid']

cv = RepeatedStratifiedKFold(n_splits=5, n_repeats=1, random_state=1)

search = BayesSearchCV(estimator=SVC(), search_spaces=params, n_jobs=-1, cv=cv)

search.fit(X, y)

print(search.best_score_)
print(search.best_params_)
# Out:
# /usr/local/lib/python3.7/dist-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /usr/local/lib/python3.7/dist-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /usr/local/lib/python3.7/dist-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /usr/local/lib/python3.7/dist-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /usr/local/lib/python3.7/dist-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# ...
